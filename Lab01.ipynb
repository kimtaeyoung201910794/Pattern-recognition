# %%
# 201910794 김태영 과제제출
# 구글 드라이브 링크: https://drive.google.com/drive/folders/1rIp-jK7ED6kT-6OaSTjCOds4uIt5o7Gw?usp=drive_link
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
img = cv2.imread("drive/MyDrive/PR201910794/img/lab01_rainbow (1).jpg")

# %%
cv2_imshow(img)

# %%
img.shape

# %%
img = cv2.resize(img, (500,400))

# %%
cv2_imshow(img)

# %%
cv2_imshow(img[:, :, 0])

# %%
plt.hist(img[:, :, 0].flatten(), bins=256)
# Out:
# (array([2.6538e+04, 8.7590e+03, 1.2930e+03, 1.2210e+03, 1.0570e+03,
#         1.0160e+03, 6.7000e+02, 1.0930e+03, 1.1870e+03, 1.4530e+03,
#         1.5930e+03, 1.2870e+03, 1.4950e+03, 1.5970e+03, 2.0090e+03,
#         1.4080e+03, 1.7140e+03, 1.6910e+03, 1.6240e+03, 1.2840e+03,
#         1.9120e+03, 1.5460e+03, 1.5180e+03, 2.0930e+03, 2.6730e+03,
#         1.9830e+03, 1.8770e+03, 3.1480e+03, 2.6070e+03, 1.8250e+03,
#         2.4980e+03, 2.8020e+03, 2.3670e+03, 2.2760e+03, 1.7520e+03,
#         2.0930e+03, 1.1290e+03, 2.6280e+03, 1.9210e+03, 1.4780e+03,
#         1.3190e+03, 9.2600e+02, 3.1000e+02, 1.1800e+02, 3.1100e+02,
#         1.4700e+02, 1.7400e+02, 3.0400e+02, 1.5600e+02, 1.6000e+02,
#         3.5400e+02, 1.7000e+02, 3.7400e+02, 1.7600e+02, 1.9900e+02,
#         3.7500e+02, 2.0200e+02, 2.2400e+02, 3.7100e+02, 2.2500e+02,
#         3.9700e+02, 2.3000e+02, 3.2100e+02, 3.1300e+02, 2.4500e+02,
#         2.5400e+02, 2.6000e+02, 4.4000e+02, 2.6000e+02, 4.4500e+02,
# ...

# %%
plt.hist(img[:, :, 1].flatten(), bins=256)
# Out:
# (array([ 267.,  193.,  177.,  445.,  366.,  212.,  437.,  385.,  217.,
#          386.,  215.,  248.,  584.,  280.,  586.,  687.,  537.,  816.,
#          841.,  749.,  722.,  676.,  857.,  874.,  729.,  893.,  914.,
#          753.,  939.,  956.,  781., 1183.,  825.,  837., 1047., 1032.,
#            0.,  895., 1077., 1040., 1070., 1411., 1584., 2183., 2322.,
#         2321., 2060., 2295., 2180., 1753., 2295., 2015., 1803., 1933.,
#         1720., 1823., 1626., 1381.,  793.,  651.,  649.,  521.,  707.,
#          883.,  699.,  549.,  936.,  637.,  873.,  732.,  744.,  926.,
#          698.,    0.,  734.,  918.,  559.,  945.,  716.,  614., 1033.,
#          585.,  746., 1052.,  587.,  701.,  707.,  911.,  511., 1095.,
#          710.,  497.,  904.,  512.,  924.,  684.,  688.,  539., 1047.,
#          681.,  687.,  886.,  668.,  679.,  655.,  501.,  876.,  830.,
#          667.,    0.,  483.,  668.,  875.,  654.,  682.,  824.,  668.,
# ...

# %%
plt.hist(img[:, :, 2].flatten(), bins=256)
# Out:
# (array([   13.,   188.,   679.,  1270.,  1536.,  1595.,  1727.,  1708.,
#          1683.,  1931.,  1977.,  2132.,  2217.,  2207.,  2320.,  2514.,
#          3033.,  4885.,  6451.,  8691.,  8327.,  8042.,  6652.,  3513.,
#          1624.,   511.,   961.,   972.,   825.,   689.,   462.,   773.,
#          1023.,   641.,   579.,   646.,     0.,   982.,   736.,   795.,
#           431.,   396.,  1092.,   580.,   742.,   913.,   551.,   551.,
#           536.,   740.,   565.,   446.,   883.,   296.,   685.,  1063.,
#           267.,   499.,   712.,   833.,   292.,   503.,   664.,   687.,
#           672.,   481.,   487.,   499.,  1044.,   474.,   661.,   476.,
#           317.,     0.,   625.,  1052.,   519.,   917.,   323.,   846.,
#           338.,   711.,   484.,   503.,   839.,   257.,   846.,   455.,
#           254.,   281.,   441.,   288.,   426.,   210.,   284.,   461.,
#           254.,   258.,   257.,   396.,   485.,   227.,   254.,   442.,
# ...

# %%
imggray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(imggray)

# %%
imggray.flatten().shape

# %%
plt.hist(imggray.flatten(), bins=256)

# %%
grayhist = cv2.calcHist([imggray], [0], None, [256], [0,256])
print(grayhist.shape)

# %%
plt.plot(grayhist)
plt.hist(imggray.flatten(), bins=256)
# Out:
# (array([   6.,   31.,   87.,  162.,  248.,    0.,  264.,  313.,  396.,
#          422.,  397.,    0.,  433.,  487.,  516.,  462.,  493.,    0.,
#          565.,  563.,  545.,  555.,    0.,  659.,  612.,  622.,  669.,
#          706.,    0.,  743.,  758.,  873.,  884.,  889.,    0.,  931.,
#          968., 1003.,  971.,    0., 1075., 1017., 1098., 1125., 1179.,
#            0., 1742., 1574., 2143., 2298., 1890.,    0., 1964., 2448.,
#         1847., 1898.,    0., 2449., 2194., 1828., 2380., 2137.,    0.,
#         1738., 2128., 2071., 1673., 2058.,    0., 2347., 1554., 1751.,
#         1690.,    0.,  934., 1139., 1114.,  962., 1275.,    0.,  952.,
#         1112., 1093., 1081.,  928.,    0., 1126., 1052., 1089., 1103.,
#         1054.,    0., 1078.,  883.,  922., 1245.,    0.,  874., 1242.,
#          900.,  874., 1239.,    0., 1085.,  849., 1056., 1069.,  855.,
#            0., 1100.,  968., 1008., 1109.,    0.,  869., 1069., 1041.,
# ...
